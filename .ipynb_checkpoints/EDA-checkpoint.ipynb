# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib_inline.backend_inline

# %%
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


entree_df = pd.read_csv('mc_entree_with_price.csv')
entree_df = entree_df.drop(columns = 'Time').rename(columns ={ 'Unnamed: 0': "Item_Name"})
entree_df
# Out:
#                                Item_Name  Calories  Total_Fat  Total_Carbs  \
# 0          spicy-crispy-chicken-sandwich     530.0       26.0         48.0
# 1                                big-mac     550.0       30.0         45.0
# 2              chicken-mcnuggets-4-piece     170.0       10.0         10.0
# 3            quarter-pounder-with-cheese     520.0       26.0         42.0
# 4     double-quarter-pounder-with-cheese     740.0       42.0         43.0
# 5     deluxe-quarter-pounder-with-cheese     630.0       37.0         44.0
# 6                               mcdouble     400.0       20.0         33.0
# 7      bacon-quarter-pounder-with-cheese     630.0       35.0         43.0
# 8                           cheeseburger     300.0       13.0         32.0
# 9                    double-cheeseburger     450.0       24.0         34.0
# 10                             hamburger     250.0        9.0         31.0
# 11  spicy-deluxe-crispy-chicken-sandwich     530.0       26.0         49.0
# 12               crispy-chicken-sandwich     470.0       20.0         46.0
# 13        deluxe-crispy-chicken-sandwich     530.0       26.0         48.0
# 14                             mcchicken     400.0       21.0         39.0
# 15                          filet-o-fish     390.0       19.0         39.0
#
#     Protein  Saturated_Fat  Dietary_Fiber  Calcium  Total_Sugars  Iron  \
# 0      27.0            4.0            2.0     30.0           9.0   2.5
# 1      25.0           11.0            3.0    120.0           9.0   4.5
# 2       9.0            1.5            0.0      6.0           0.0   0.5
# 3      30.0           12.0            2.0    190.0          10.0   4.0
# 4      48.0           20.0            2.0    200.0          10.0   6.0
# 5      30.0           14.0            3.0    200.0          11.0   4.5
# 6      22.0            9.0            2.0    100.0           7.0   3.5
# 7      36.0           15.0            3.0    190.0          10.0   4.5
# 8      15.0            6.0            2.0    100.0           7.0   3.0
# 9      25.0           11.0            2.0    180.0           7.0   3.5
# 10     12.0            3.5            1.0     20.0           6.0   3.0
# 11     27.0            4.0            2.0     30.0          10.0   2.5
# 12     26.0            5.0            1.0     30.0           9.0   2.0
# 13     27.0            4.0            2.0     30.0          10.0   2.5
# 14     14.0            3.5            1.0     20.0           5.0   2.5
# 15     16.0            4.0            2.0     60.0           5.0   2.0
#
#     Cholesterol  Vitamin_D  Potassium  Sodium  Price
# 0          65.0        0.0      440.0  1320.0   6.09
# 1          80.0        0.0      380.0  1010.0   5.99
# 2          25.0        0.0      140.0   330.0   2.49
# 3          95.0        0.0      420.0  1140.0   5.99
# 4         165.0        0.0      660.0  1360.0   7.39
# 5         105.0        0.0      500.0  1210.0   7.39
# 6          70.0        0.0      330.0   920.0   3.09
# 7         115.0        0.0      490.0  1470.0   7.59
# 8          40.0        0.0      220.0   720.0   1.99
# 9          85.0        0.0      350.0  1120.0   3.19
# 10         30.0        0.0      200.0   510.0   1.79
# 11         65.0        0.0      510.0  1200.0   7.09
# 12         70.0        0.0      420.0  1140.0   6.09
# 13         65.0        0.0      490.0  1050.0   7.09
# 14         40.0        0.0      320.0   560.0   2.69
# 15         40.0        0.0      300.0   580.0   5.89

# %% [markdown]
# # Viewing Correlations to Calories

# %%
sns.heatmap(entree_df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From this heatmap, I can see that none of the items have any Vitamin D, and that the strongest connections to calories seems to be Total Fat, Protein, and surprisingly Potassium.

# %%
sns.scatterplot(x=entree_df['Calories'], y=entree_df['Protein'])
plt.title('Correlation between Protein and Calories');

# %%
sns.scatterplot(x=entree_df['Calories'], y=entree_df['Potassium'])
plt.title('Correlation between Potassium and Calories');

# %%
sns.scatterplot(x=entree_df['Calories'], y=entree_df['Total_Fat'])
plt.title('Correlation between Total Fat and Calories');

# %%
sns.scatterplot(x=entree_df['Calories'], y=entree_df['Calcium'])
plt.title('Calories to Calcium Comparison');

# %% [markdown]
# Calcium does not seem to be connected to calories, having the lowest correlation. This is probably because it is primarily coming from dairy products like cheese

# %%
calsproteinratio = []
for item in range(len(entree_df['Calories'])):
    cals = entree_df["Calories"][item]
    protein = entree_df["Protein"][item]
    ratio = cals/protein
    calsproteinratio.append(ratio)
    
entree_df['Cals_Protein_Ratio'] = calsproteinratio
entree_df
# Out:
#                                Item_Name  Calories  Total_Fat  Total_Carbs  \
# 0          spicy-crispy-chicken-sandwich     530.0       26.0         48.0
# 1                                big-mac     550.0       30.0         45.0
# 2              chicken-mcnuggets-4-piece     170.0       10.0         10.0
# 3            quarter-pounder-with-cheese     520.0       26.0         42.0
# 4     double-quarter-pounder-with-cheese     740.0       42.0         43.0
# 5     deluxe-quarter-pounder-with-cheese     630.0       37.0         44.0
# 6                               mcdouble     400.0       20.0         33.0
# 7      bacon-quarter-pounder-with-cheese     630.0       35.0         43.0
# 8                           cheeseburger     300.0       13.0         32.0
# 9                    double-cheeseburger     450.0       24.0         34.0
# 10                             hamburger     250.0        9.0         31.0
# 11  spicy-deluxe-crispy-chicken-sandwich     530.0       26.0         49.0
# 12               crispy-chicken-sandwich     470.0       20.0         46.0
# 13        deluxe-crispy-chicken-sandwich     530.0       26.0         48.0
# 14                             mcchicken     400.0       21.0         39.0
# 15                          filet-o-fish     390.0       19.0         39.0
#
#     Protein  Saturated_Fat  Dietary_Fiber  Calcium  Total_Sugars  Iron  \
# 0      27.0            4.0            2.0     30.0           9.0   2.5
# 1      25.0           11.0            3.0    120.0           9.0   4.5
# 2       9.0            1.5            0.0      6.0           0.0   0.5
# 3      30.0           12.0            2.0    190.0          10.0   4.0
# 4      48.0           20.0            2.0    200.0          10.0   6.0
# 5      30.0           14.0            3.0    200.0          11.0   4.5
# 6      22.0            9.0            2.0    100.0           7.0   3.5
# 7      36.0           15.0            3.0    190.0          10.0   4.5
# 8      15.0            6.0            2.0    100.0           7.0   3.0
# 9      25.0           11.0            2.0    180.0           7.0   3.5
# 10     12.0            3.5            1.0     20.0           6.0   3.0
# 11     27.0            4.0            2.0     30.0          10.0   2.5
# 12     26.0            5.0            1.0     30.0           9.0   2.0
# 13     27.0            4.0            2.0     30.0          10.0   2.5
# 14     14.0            3.5            1.0     20.0           5.0   2.5
# 15     16.0            4.0            2.0     60.0           5.0   2.0
#
#     Cholesterol  Vitamin_D  Potassium  Sodium  Price  Cals_Protein_Ratio
# 0          65.0        0.0      440.0  1320.0   6.09           19.629630
# 1          80.0        0.0      380.0  1010.0   5.99           22.000000
# 2          25.0        0.0      140.0   330.0   2.49           18.888889
# 3          95.0        0.0      420.0  1140.0   5.99           17.333333
# 4         165.0        0.0      660.0  1360.0   7.39           15.416667
# 5         105.0        0.0      500.0  1210.0   7.39           21.000000
# 6          70.0        0.0      330.0   920.0   3.09           18.181818
# 7         115.0        0.0      490.0  1470.0   7.59           17.500000
# 8          40.0        0.0      220.0   720.0   1.99           20.000000
# 9          85.0        0.0      350.0  1120.0   3.19           18.000000
# 10         30.0        0.0      200.0   510.0   1.79           20.833333
# 11         65.0        0.0      510.0  1200.0   7.09           19.629630
# 12         70.0        0.0      420.0  1140.0   6.09           18.076923
# 13         65.0        0.0      490.0  1050.0   7.09           19.629630
# 14         40.0        0.0      320.0   560.0   2.69           28.571429
# 15         40.0        0.0      300.0   580.0   5.89           24.375000

# %%
bar = sns.barplot(y='Item_Name', x='Cals_Protein_Ratio', data=entree_df, color = 'orange', order=entree_df.sort_values('Cals_Protein_Ratio').Item_Name).set(title='Calories Per Gram of Protein')
plt.xticks(rotation=90);

# %% [markdown]
# ## From this barplot, we can see that the double quarter pounder with cheese has less calories per gram of protein, while the mcchicken has the most calories per gram of protein

# %%
pricepercal = []
for item in range(len(entree_df['Calories'])):
    cals = entree_df["Calories"][item]
    price = entree_df["Price"][item]
    ratio = price/cals
    pricepercal.append(ratio)
    
entree_df['Price_Per_Cal'] = pricepercal
entree_df
# Out:
#                                Item_Name  Calories  Total_Fat  Total_Carbs  \
# 0          spicy-crispy-chicken-sandwich     530.0       26.0         48.0
# 1                                big-mac     550.0       30.0         45.0
# 2              chicken-mcnuggets-4-piece     170.0       10.0         10.0
# 3            quarter-pounder-with-cheese     520.0       26.0         42.0
# 4     double-quarter-pounder-with-cheese     740.0       42.0         43.0
# 5     deluxe-quarter-pounder-with-cheese     630.0       37.0         44.0
# 6                               mcdouble     400.0       20.0         33.0
# 7      bacon-quarter-pounder-with-cheese     630.0       35.0         43.0
# 8                           cheeseburger     300.0       13.0         32.0
# 9                    double-cheeseburger     450.0       24.0         34.0
# 10                             hamburger     250.0        9.0         31.0
# 11  spicy-deluxe-crispy-chicken-sandwich     530.0       26.0         49.0
# 12               crispy-chicken-sandwich     470.0       20.0         46.0
# 13        deluxe-crispy-chicken-sandwich     530.0       26.0         48.0
# 14                             mcchicken     400.0       21.0         39.0
# 15                          filet-o-fish     390.0       19.0         39.0
#
#     Protein  Saturated_Fat  Dietary_Fiber  Calcium  Total_Sugars  Iron  \
# 0      27.0            4.0            2.0     30.0           9.0   2.5
# 1      25.0           11.0            3.0    120.0           9.0   4.5
# 2       9.0            1.5            0.0      6.0           0.0   0.5
# 3      30.0           12.0            2.0    190.0          10.0   4.0
# 4      48.0           20.0            2.0    200.0          10.0   6.0
# 5      30.0           14.0            3.0    200.0          11.0   4.5
# 6      22.0            9.0            2.0    100.0           7.0   3.5
# 7      36.0           15.0            3.0    190.0          10.0   4.5
# 8      15.0            6.0            2.0    100.0           7.0   3.0
# 9      25.0           11.0            2.0    180.0           7.0   3.5
# 10     12.0            3.5            1.0     20.0           6.0   3.0
# 11     27.0            4.0            2.0     30.0          10.0   2.5
# 12     26.0            5.0            1.0     30.0           9.0   2.0
# 13     27.0            4.0            2.0     30.0          10.0   2.5
# 14     14.0            3.5            1.0     20.0           5.0   2.5
# 15     16.0            4.0            2.0     60.0           5.0   2.0
#
#     Cholesterol  Vitamin_D  Potassium  Sodium  Price  Cals_Protein_Ratio  \
# 0          65.0        0.0      440.0  1320.0   6.09           19.629630
# 1          80.0        0.0      380.0  1010.0   5.99           22.000000
# 2          25.0        0.0      140.0   330.0   2.49           18.888889
# 3          95.0        0.0      420.0  1140.0   5.99           17.333333
# 4         165.0        0.0      660.0  1360.0   7.39           15.416667
# 5         105.0        0.0      500.0  1210.0   7.39           21.000000
# 6          70.0        0.0      330.0   920.0   3.09           18.181818
# 7         115.0        0.0      490.0  1470.0   7.59           17.500000
# 8          40.0        0.0      220.0   720.0   1.99           20.000000
# 9          85.0        0.0      350.0  1120.0   3.19           18.000000
# 10         30.0        0.0      200.0   510.0   1.79           20.833333
# 11         65.0        0.0      510.0  1200.0   7.09           19.629630
# 12         70.0        0.0      420.0  1140.0   6.09           18.076923
# 13         65.0        0.0      490.0  1050.0   7.09           19.629630
# 14         40.0        0.0      320.0   560.0   2.69           28.571429
# 15         40.0        0.0      300.0   580.0   5.89           24.375000
#
#     Price_Per_Cal
# 0        0.011491
# 1        0.010891
# 2        0.014647
# 3        0.011519
# 4        0.009986
# 5        0.011730
# 6        0.007725
# 7        0.012048
# 8        0.006633
# 9        0.007089
# 10       0.007160
# 11       0.013377
# 12       0.012957
# 13       0.013377
# 14       0.006725
# 15       0.015103

# %%
bar = sns.barplot(y='Item_Name', x='Price_Per_Cal', data=entree_df, color="orange", order=entree_df.sort_values('Price_Per_Cal').Item_Name ).set(title='Price Per Calorie')
plt.xticks(rotation=90);

# %% [markdown]
# ## However, here we see that the Cheeseburger is the best price for the calories, while the filet-o-fish is the most expensive per calorie. (The McChicken is .6 cents per calorie, the Filet-o-Fish is 1.5 cents per calorie)

# %%
priceperprot = []
for item in range(len(entree_df['Protein'])):
    protein = entree_df["Protein"][item]
    price = entree_df["Price"][item]
    ratio = price/protein
    priceperprot.append(ratio)
    
entree_df['Price_Per_Protein'] = priceperprot
entree_df
# Out:
#                                Item_Name  Calories  Total_Fat  Total_Carbs  \
# 0          spicy-crispy-chicken-sandwich     530.0       26.0         48.0
# 1                                big-mac     550.0       30.0         45.0
# 2              chicken-mcnuggets-4-piece     170.0       10.0         10.0
# 3            quarter-pounder-with-cheese     520.0       26.0         42.0
# 4     double-quarter-pounder-with-cheese     740.0       42.0         43.0
# 5     deluxe-quarter-pounder-with-cheese     630.0       37.0         44.0
# 6                               mcdouble     400.0       20.0         33.0
# 7      bacon-quarter-pounder-with-cheese     630.0       35.0         43.0
# 8                           cheeseburger     300.0       13.0         32.0
# 9                    double-cheeseburger     450.0       24.0         34.0
# 10                             hamburger     250.0        9.0         31.0
# 11  spicy-deluxe-crispy-chicken-sandwich     530.0       26.0         49.0
# 12               crispy-chicken-sandwich     470.0       20.0         46.0
# 13        deluxe-crispy-chicken-sandwich     530.0       26.0         48.0
# 14                             mcchicken     400.0       21.0         39.0
# 15                          filet-o-fish     390.0       19.0         39.0
#
#     Protein  Saturated_Fat  Dietary_Fiber  Calcium  Total_Sugars  Iron  \
# 0      27.0            4.0            2.0     30.0           9.0   2.5
# 1      25.0           11.0            3.0    120.0           9.0   4.5
# 2       9.0            1.5            0.0      6.0           0.0   0.5
# 3      30.0           12.0            2.0    190.0          10.0   4.0
# 4      48.0           20.0            2.0    200.0          10.0   6.0
# 5      30.0           14.0            3.0    200.0          11.0   4.5
# 6      22.0            9.0            2.0    100.0           7.0   3.5
# 7      36.0           15.0            3.0    190.0          10.0   4.5
# 8      15.0            6.0            2.0    100.0           7.0   3.0
# 9      25.0           11.0            2.0    180.0           7.0   3.5
# 10     12.0            3.5            1.0     20.0           6.0   3.0
# 11     27.0            4.0            2.0     30.0          10.0   2.5
# 12     26.0            5.0            1.0     30.0           9.0   2.0
# 13     27.0            4.0            2.0     30.0          10.0   2.5
# 14     14.0            3.5            1.0     20.0           5.0   2.5
# 15     16.0            4.0            2.0     60.0           5.0   2.0
#
#     Cholesterol  Vitamin_D  Potassium  Sodium  Price  Cals_Protein_Ratio  \
# 0          65.0        0.0      440.0  1320.0   6.09           19.629630
# 1          80.0        0.0      380.0  1010.0   5.99           22.000000
# 2          25.0        0.0      140.0   330.0   2.49           18.888889
# 3          95.0        0.0      420.0  1140.0   5.99           17.333333
# 4         165.0        0.0      660.0  1360.0   7.39           15.416667
# 5         105.0        0.0      500.0  1210.0   7.39           21.000000
# 6          70.0        0.0      330.0   920.0   3.09           18.181818
# 7         115.0        0.0      490.0  1470.0   7.59           17.500000
# 8          40.0        0.0      220.0   720.0   1.99           20.000000
# 9          85.0        0.0      350.0  1120.0   3.19           18.000000
# 10         30.0        0.0      200.0   510.0   1.79           20.833333
# 11         65.0        0.0      510.0  1200.0   7.09           19.629630
# 12         70.0        0.0      420.0  1140.0   6.09           18.076923
# 13         65.0        0.0      490.0  1050.0   7.09           19.629630
# 14         40.0        0.0      320.0   560.0   2.69           28.571429
# 15         40.0        0.0      300.0   580.0   5.89           24.375000
#
#     Price_Per_Cal  Price_Per_Protein
# 0        0.011491           0.225556
# 1        0.010891           0.239600
# 2        0.014647           0.276667
# 3        0.011519           0.199667
# 4        0.009986           0.153958
# 5        0.011730           0.246333
# 6        0.007725           0.140455
# 7        0.012048           0.210833
# 8        0.006633           0.132667
# 9        0.007089           0.127600
# 10       0.007160           0.149167
# 11       0.013377           0.262593
# 12       0.012957           0.234231
# 13       0.013377           0.262593
# 14       0.006725           0.192143
# 15       0.015103           0.368125

# %%
bar = sns.barplot(y='Item_Name', x='Price_Per_Protein', data=entree_df, color='orange', order=entree_df.sort_values('Price_Per_Protein').Item_Name).set(title='Price Per Gram Of Protein')
plt.xticks(rotation=90);

# %% [markdown]
# ## When looking at the price per gram of protein, once again the filet-o-fish shows itself to be the most expensive. The double cheesburger, however, is the cheapest

# %% [markdown]
# From this data analysis, we can see that there is different menu items to choose depending on a person's goals. This, to me, shows the importance of the tool I am creating because being able to simply insert what your priorities are and getting the most optimal result would save a lot of headache.
